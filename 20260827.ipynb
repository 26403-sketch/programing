# %% [markdown]
# <a href="https://colab.research.google.com/github/26403-sketch/programing/blob/main/20260827.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
print("반갑습니다.")
# Out:
# 반갑습니다.
